# %%
def modify(s):
        if s[0]== s[0].lower():
            s=s.lower()
            
        else:
            s.upper()
        return s
        
s="aAAAAoOOAKMSSdff"
print(modify(s))
# Out:
# aaaaaoooakmssdff

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
