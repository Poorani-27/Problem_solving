# %%
n=20
print("square value")
for i in range(1,n+1):
    
    print(i**2,end=" ")
print("\ncube value")
for i in range(1,n+1):
    
    print(i**3,end=" ")
# Out:
# square value
# 1 4 9 16 25 36 49 64 81 100 121 144 169 196 225 256 289 324 361 400
# cube value
# 1 8 27 64 125 216 343 512 729 1000 1331 1728 2197 2744 3375 4096 4913 5832 6859 8000

# %%
n=64
cube_root=n**(1/3)
print(cube_root)
# Out:
# 3.9999999999999996

# %%
n=361
sqrt_root=n**(1/2) 
print(sqrt_root)
# Out:
# 19.0

# %%
def countSquares(N):
        count=0
        sqr=[i*i for i in range(1,N)]
        for i in range(1,N):
            if i in sqr:
                count +=1
        return count
print(countSquares(6))
# Out:
# 2

# %%
arr = [-1, -2, -3, 4, 5, 6, 7] 
d = 2
res=(arr[d:])+(arr[:d])
print(res)
# Out:
# [-3, 4, 5, 6, 7, -1, -2]

# %%
def find_tax(salary):
    if not isinstance(salary,(int,float)) or salary <0 :
        print(f"Invalid Input {salary}")
    tax=0
    if 0 < salary <=250000:
        return ("Tax = Nil")
    elif 250000 < salary <=500000:
        tax= salary *10/100
        return tax
    elif 500000 < salary <= 1000000 :
        tax=salary * 20/100
        return tax
    else:
        tax=salary*30/100
        return tax

salary = 1000000
result=int(find_tax(salary))
print(f"Tax Value for {salary} : {result} ")
# Out:
# Tax Value for 1000000 : 200000

# %%
def find_salary(salary):
    if not isinstance(salary,(int,float)) or salary<0:
        return ("Invalid input")
    tax=0
    if salary > 1000000 :
        tax +=(salary -1000000) *0.30
        salary = 1000000
    if 500000 < salary <= 1000000 :
        tax +=(salary -500000) *0.20
        salary = 500000
    if 250000 < salary <=500000 :
        tax +=(salary -250000) *0.10
        salary = 250000
    if 0 < salary < 250000 :
        return "Tax = Nil"
    return tax
salary=1000000
result=int(find_salary(salary))
print(f"Total Tax Value for {salary} = {result}")
# Out:
# Total Tax Value for 1000000 = 125000

# %%
# Out:
# total tax value for 1000000 = 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
