# %% [markdown]
# Reverse The String
# ![image.png](attachment:image.png)

# %%
string='hello welcome'.split(" ")
reversed_string=' '.join(reversed(string))
print(reversed_string)
# Out:
# welcome hello

# %% [markdown]
# Time complexity :O(n)
# space complexity:O(n)
