# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=int(input())
arr=[]
for i in range(n):
    a=str(input())
    arr.append(a)
common_prefix=[]
# Out:
# ['hi', 'hello', 'hwr']

# %%
# Out:
# e
