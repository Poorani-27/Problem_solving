# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def remove_space(string):
    print("length including space",len(string))
    string = string.replace(" ", "")
    print("length without space",len(string))

remove_space("geeks for geeks best")
# Out:
# length including space 20
# length without space 17
