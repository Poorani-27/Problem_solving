# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def check_string(string,substring):
    if substring in string:
        return True
    return False
    
print(check_string("geeksforgeeks","for"))
# Out:
# True
