# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def frequency(string):
    string=string.split(" ")
    for a in string:
        print(a, string.count(a))

frequency("geeks for geeks coding")
# Out:
# geeks 2
# for 1
# geeks 2
# coding 1
