# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def reversed_string(string):
    string = string.split(" ")
    
    return  " ".join(string[::-1])

string="geeks quiz practice question"
print(f"{string}--original string \n{reversed_string(string)} -- reversed string")
# Out:
# geeks quiz practice question--original string
# question practice quiz geeks -- reversed string
