# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def remove_elements(string):
    modified_string=[]
    for element in string:
        if element.isalpha():
            modified_string.append(element)
    return "".join(modified_string)

print(remove_elements("Geeksforgeeks123Geeks"))
# Out:
# GeeksforgeeksGeeks
