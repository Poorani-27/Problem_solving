# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def reverse_string(string):
    string = string.split(" ")
    reverse_string=string[::-1]
    print(" ".join(reverse_string))
reverse_string("This is decent")
# Out:
# decent is This

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def is_palindrome(string):
    print( string == string[::-1])

is_palindrome("malayalam")
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def remove_spaces(s):
    return s.replace(" ","")

res=remove_spaces( "A b cbd sw w")
print(res)
# Out:
# Abcbdsww

# %% [markdown]
# ![image.png](attachment:image.png)
